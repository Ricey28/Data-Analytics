# %%
#Install of Pandas to the Notebook

# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#Importing Pandas to this Notebook

import pandas as pd

import import_ipynb

import dataframeUtilities as dfu
# Out:
# importing Jupyter notebook from dataframeUtilities.ipynb

# %%
#Import of the chosen Open Source Dataset Rental Prices By Quarter:https://www.rtb.ie/research/average-rent-dataset

importedwages = 'Averageannualirishwagesperyear.csv'

datawages = pd.read_csv(importedwages)

# %%
#Viewing the new Dataset headers and columns to ensure it has the information required

datawages.head(11)
# Out:
#    COUNTRY  Country SERIES  ...         Value  Flag Codes  Flags
# 0      IRL  Ireland  CPNCU  ...  15349.510969         NaN    NaN
# 1      IRL  Ireland  CPNCU  ...  16411.982778         NaN    NaN
# 2      IRL  Ireland  CPNCU  ...  17601.759896         NaN    NaN
# 3      IRL  Ireland  CPNCU  ...  18872.361646         NaN    NaN
# 4      IRL  Ireland  CPNCU  ...  19507.798965         NaN    NaN
# 5      IRL  Ireland  CPNCU  ...  20402.137467         NaN    NaN
# 6      IRL  Ireland  CPNCU  ...  21420.869926         NaN    NaN
# 7      IRL  Ireland  CPNCU  ...  23208.538197         NaN    NaN
# 8      IRL  Ireland  CPNCU  ...  25550.419681         NaN    NaN
# 9      IRL  Ireland  CPNCU  ...  26894.370181         NaN    NaN
# 10     IRL  Ireland  CPNCU  ...  28790.180399         NaN    NaN
#
# [11 rows x 15 columns]

# %%
datawages = dfu.nan_clr_df(datawages)

# %%
print(datawages)
# Out:
#    COUNTRY  Country SERIES  ... PowerCode Code  PowerCode         Value
# 0      IRL  Ireland  CPNCU  ...              0      Units  15349.510969
# 1      IRL  Ireland  CPNCU  ...              0      Units  16411.982778
# 2      IRL  Ireland  CPNCU  ...              0      Units  17601.759896
# 3      IRL  Ireland  CPNCU  ...              0      Units  18872.361646
# 4      IRL  Ireland  CPNCU  ...              0      Units  19507.798965
# 5      IRL  Ireland  CPNCU  ...              0      Units  20402.137467
# 6      IRL  Ireland  CPNCU  ...              0      Units  21420.869926
# 7      IRL  Ireland  CPNCU  ...              0      Units  23208.538197
# 8      IRL  Ireland  CPNCU  ...              0      Units  25550.419681
# 9      IRL  Ireland  CPNCU  ...              0      Units  26894.370181
# 10     IRL  Ireland  CPNCU  ...              0      Units  28790.180399
# 11     IRL  Ireland  CPNCU  ...              0      Units  31012.206576
# ...

# %%
#Checking the Time column on the new Dataset to see what format it is currently. As this column was an int, I decided to alter the other dataset to include this column to use as an identifier for merging the Datasets

print(datawages['Time'].dtype)
# Out:
# int64
